# %%
import pandas as pd
import numpy as np
import dvc.api

# %%
data = pd.read_csv("../data/data.csv")
data = data.drop(columns="id")
data
# Out:
#            f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0     -0.389420 -0.912791  0.648951  0.589045 -0.830817  0.733624  2.258560
# 1     -0.689249 -0.453954  0.654175  0.995248 -1.653020  0.863810 -0.090651
# 2      0.809079  0.324568 -1.170602 -0.624491  0.105448  0.783948  1.988301
# 3     -0.500923  0.229049  0.264109  0.231520  0.415012 -1.221269  0.138850
# 4     -0.671268 -1.039533 -0.270155 -1.830264 -0.290108 -1.852809  0.781898
# ...         ...       ...       ...       ...       ...       ...       ...
# 97995  0.237591  1.657034 -0.689282  0.313710 -0.299039  0.329139  1.607378
# 97996  0.322696  0.710411  0.562625 -1.321713 -0.357708  0.182024  0.178558
# 97997 -0.249364 -0.459545  1.886122 -1.340310  0.195029 -0.559520 -0.379767
# 97998  0.311408  2.185237  0.761367  0.436723  0.464967  0.062321 -0.334025
# 97999  0.755170  0.567483  1.456767 -0.579071 -0.048474 -1.206240  0.784305
#
#        f_07  f_08  f_09  ...      f_19      f_20      f_21      f_22  \
# 0         2    13    14  ... -0.478412 -0.757002 -0.763635 -1.090369
# 1         2     3     6  ... -0.428791 -0.089908 -1.784204 -0.839474
# 2         5    11     5  ... -0.413534 -1.602377  1.190984  3.267116
# 3         6     2    13  ...  0.619283  1.287801  0.532837  1.036631
# 4         8     7     5  ... -1.628830 -0.434948  0.322505  0.284326
# ...     ...   ...   ...  ...       ...       ...       ...       ...
# 97995     5     7     8  ... -0.290116 -0.258141 -0.973640  1.369508
# 97996     3     9     2  ...  0.117687  1.388242  0.342400  1.680537
# 97997     8     9    10  ... -0.850223 -1.787648 -1.268115 -1.508330
# 97998     1     8    11  ... -0.010839  1.118906  1.565765  0.358480
# 97999     0    11     3  ...  1.180805 -0.925705 -1.368680 -2.465425
#
#            f_23      f_24      f_25      f_26      f_27      f_28
# 0      1.142641 -0.884274  1.137896  1.309073  1.463002  0.813527
# 1      0.459685  1.759412 -0.275422 -0.852168  0.562457 -2.680541
# 2     -0.088322 -2.168635 -0.974989  1.335763 -1.110655 -3.630723
# 3     -2.041828  1.440490 -1.900191 -0.630771 -0.050641  0.238333
# 4     -2.438365  1.473930 -1.044684  1.602686 -0.405263 -1.987263
# ...         ...       ...       ...       ...       ...       ...
# 97995  0.391055  2.152426 -0.208944 -1.475403  0.298448  0.445039
# 97996 -0.860409  0.579165  1.162692  0.134994  0.994666  0.727642
# 97997  1.945622  1.503645  0.194968  2.142693  1.646042  0.641466
# 97998  0.547615  1.224439 -0.537998 -1.610954 -0.616227 -0.066211
# 97999  1.453582 -1.685122  0.129689 -0.970897  1.404988 -0.711098
#
# [98000 rows x 29 columns]

# %%
data.describe()
# Out:
#                f_00          f_01          f_02          f_03          f_04  \
# count  98000.000000  98000.000000  98000.000000  98000.000000  98000.000000
# mean       0.001220      0.005580     -0.001042     -0.000700     -0.003522
# std        1.002801      1.000742      1.001373      1.000422      1.003061
# min       -4.732235     -4.202795     -4.377021     -4.010826     -4.535903
# 25%       -0.675226     -0.670985     -0.672779     -0.672540     -0.682510
# 50%        0.002022      0.006650     -0.000324     -0.003185     -0.003307
# 75%        0.677271      0.677746      0.677086      0.672097      0.677589
# max        4.490521      4.324974      4.560247      4.399373      4.050549
#
#                f_05          f_06          f_07          f_08          f_09  \
# count  98000.000000  98000.000000  98000.000000  98000.000000  98000.000000
# mean      -0.001612     -0.003042      5.545918      6.763061      8.193163
# std        1.000532      0.997434      3.691840      4.152348      5.904919
# min       -4.300767     -4.894525      0.000000      0.000000      0.000000
# 25%       -0.675066     -0.680421      3.000000      4.000000      4.000000
# 50%        0.001024     -0.002053      5.000000      6.000000      7.000000
# 75%        0.673344      0.668112      8.000000      9.000000     11.000000
# max        4.710316      3.998595     32.000000     30.000000     44.000000
#
#        ...          f_19          f_20          f_21          f_22  \
# count  ...  98000.000000  98000.000000  98000.000000  98000.000000
# mean   ...     -0.004513     -0.000515     -0.001670     -0.038752
# std    ...      1.004372      1.002962      0.999703      1.477858
# min    ...     -4.894525     -4.732235     -4.438130     -6.873999
# 25%    ...     -0.678773     -0.679777     -0.675147     -1.022964
# 50%    ...     -0.000587     -0.000806      0.000819     -0.056687
# 75%    ...      0.672149      0.675437      0.676881      0.930158
# max    ...      4.560247      4.399373      4.135419      6.517721
#
#                f_23          f_24          f_25          f_26          f_27  \
# count  98000.000000  98000.000000  98000.000000  98000.000000  98000.000000
# mean      -0.220002      0.166434     -0.064309     -0.062540      0.098472
# std        1.494836      1.543014      1.576086      1.428055      1.305407
# min       -8.234305     -7.792363     -6.593842     -7.375719     -7.335556
# 25%       -1.203204     -0.903385     -1.128966     -0.975680     -0.746489
# 50%       -0.219046      0.167074     -0.099221     -0.070852      0.082230
# 75%        0.764690      1.217432      0.987684      0.843212      0.925306
# max        6.054831      7.527271      7.544731      7.005608      7.205971
#
#                f_28
# count  98000.000000
# mean      -0.230910
# std        1.528476
# min       -6.954151
# 25%       -1.262606
# 50%       -0.271319
# 75%        0.770516
# max        6.977150
#
# [8 rows x 29 columns]

# %% [markdown]
# # Normalization

# %% [markdown]
# We will start by filtering data with very low variance.

# %%
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(threshold=0.01)
selected = sel.fit_transform(data)
data_sel = pd.DataFrame(selected,columns=sel.get_feature_names_out())
data_sel
# Out:
#            f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0     -0.389420 -0.912791  0.648951  0.589045 -0.830817  0.733624  2.258560
# 1     -0.689249 -0.453954  0.654175  0.995248 -1.653020  0.863810 -0.090651
# 2      0.809079  0.324568 -1.170602 -0.624491  0.105448  0.783948  1.988301
# 3     -0.500923  0.229049  0.264109  0.231520  0.415012 -1.221269  0.138850
# 4     -0.671268 -1.039533 -0.270155 -1.830264 -0.290108 -1.852809  0.781898
# ...         ...       ...       ...       ...       ...       ...       ...
# 97995  0.237591  1.657034 -0.689282  0.313710 -0.299039  0.329139  1.607378
# 97996  0.322696  0.710411  0.562625 -1.321713 -0.357708  0.182024  0.178558
# 97997 -0.249364 -0.459545  1.886122 -1.340310  0.195029 -0.559520 -0.379767
# 97998  0.311408  2.185237  0.761367  0.436723  0.464967  0.062321 -0.334025
# 97999  0.755170  0.567483  1.456767 -0.579071 -0.048474 -1.206240  0.784305
#
#        f_07  f_08  f_09  ...      f_19      f_20      f_21      f_22  \
# 0       2.0  13.0  14.0  ... -0.478412 -0.757002 -0.763635 -1.090369
# 1       2.0   3.0   6.0  ... -0.428791 -0.089908 -1.784204 -0.839474
# 2       5.0  11.0   5.0  ... -0.413534 -1.602377  1.190984  3.267116
# 3       6.0   2.0  13.0  ...  0.619283  1.287801  0.532837  1.036631
# 4       8.0   7.0   5.0  ... -1.628830 -0.434948  0.322505  0.284326
# ...     ...   ...   ...  ...       ...       ...       ...       ...
# 97995   5.0   7.0   8.0  ... -0.290116 -0.258141 -0.973640  1.369508
# 97996   3.0   9.0   2.0  ...  0.117687  1.388242  0.342400  1.680537
# 97997   8.0   9.0  10.0  ... -0.850223 -1.787648 -1.268115 -1.508330
# 97998   1.0   8.0  11.0  ... -0.010839  1.118906  1.565765  0.358480
# 97999   0.0  11.0   3.0  ...  1.180805 -0.925705 -1.368680 -2.465425
#
#            f_23      f_24      f_25      f_26      f_27      f_28
# 0      1.142641 -0.884274  1.137896  1.309073  1.463002  0.813527
# 1      0.459685  1.759412 -0.275422 -0.852168  0.562457 -2.680541
# 2     -0.088322 -2.168635 -0.974989  1.335763 -1.110655 -3.630723
# 3     -2.041828  1.440490 -1.900191 -0.630771 -0.050641  0.238333
# 4     -2.438365  1.473930 -1.044684  1.602686 -0.405263 -1.987263
# ...         ...       ...       ...       ...       ...       ...
# 97995  0.391055  2.152426 -0.208944 -1.475403  0.298448  0.445039
# 97996 -0.860409  0.579165  1.162692  0.134994  0.994666  0.727642
# 97997  1.945622  1.503645  0.194968  2.142693  1.646042  0.641466
# 97998  0.547615  1.224439 -0.537998 -1.610954 -0.616227 -0.066211
# 97999  1.453582 -1.685122  0.129689 -0.970897  1.404988 -0.711098
#
# [98000 rows x 29 columns]

# %%
len(data_sel.columns),len(data.columns)
# Out:
# (29, 29)

# %% [markdown]
# We will also check features correlation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), cmap='YlOrRd')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Features are not heavily corellated, no need for selection on this part.

# %% [markdown]
# However as there a total of 28 features, some feature extraction needs to be performed. LDA is not viable since it's supervised.
# To find out the number of clusters we will use UMAP, as it preserves distances locally.
#
# First perform standard scaling.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data_norm = pd.DataFrame(scaler.fit_transform(data),columns=data.columns)
data_norm
# Out:
#            f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0     -0.389551 -0.917695  0.649105  0.589499 -0.824775  0.734849  2.267432
# 1     -0.688544 -0.459195  0.654321  0.995533 -1.644472  0.864967 -0.087835
# 2      0.805607  0.318753 -1.167963 -0.623531  0.108638  0.785146  1.996476
# 3     -0.500743  0.223305  0.264788  0.232124  0.417259 -1.219016  0.142257
# 4     -0.670613 -1.044343 -0.268745 -1.828801 -0.285713 -1.850223  0.786963
# ...         ...       ...       ...       ...       ...       ...       ...
# 97995  0.235712  1.650239 -0.687300  0.314279 -0.294617  0.330577  1.614571
# 97996  0.320580  0.704312  0.562897 -1.320462 -0.353107  0.183539  0.182068
# 97997 -0.249885 -0.464782  1.884586 -1.339051  0.197946 -0.557614 -0.377696
# 97998  0.309323  2.178053  0.761367  0.437241  0.467061  0.063899 -0.331837
# 97999  0.751848  0.561490  1.455817 -0.578129 -0.044815 -1.203995  0.789376
#
#            f_07      f_08      f_09  ...      f_19      f_20      f_21  \
# 0     -0.960479  1.502035  0.983395  ... -0.471839 -0.754257 -0.762195
# 1     -0.960479 -0.906254 -0.371415  ... -0.422434 -0.089129 -1.783073
# 2     -0.147872  1.020377 -0.540766  ... -0.407243 -1.597140  1.193015
# 3      0.122997 -1.147082  0.814044  ...  0.621083  1.284518  0.534669
# 4      0.664735  0.057062 -0.540766  ... -1.617255 -0.433152  0.324273
# ...         ...       ...       ...  ...       ...       ...       ...
# 97995 -0.147872  0.057062 -0.032712  ... -0.284362 -0.256866 -0.972264
# 97996 -0.689610  0.538719 -1.048820  ...  0.121668  1.384664  0.344174
# 97997  0.664735  0.538719  0.305990  ... -0.842033 -1.781864 -1.266828
# 97998 -1.231348  0.297891  0.475341  ... -0.006299  1.116121  1.567909
# 97999 -1.502217  1.020377 -0.879468  ...  1.180164 -0.922462 -1.367424
#
#            f_22      f_23      f_24      f_25      f_26      f_27      f_28
# 0     -0.711585  0.911572 -0.680948  0.762783  0.960482  1.045296  0.683323
# 1     -0.541815  0.454693  1.032386 -0.133948 -0.552942  0.355435 -1.602671
# 2      2.236943  0.088090 -1.513324 -0.577814  0.979171 -0.926250 -2.224327
# 3      0.727667 -1.218753  0.825698 -1.164842 -0.397908 -0.114228  0.307002
# 4      0.218614 -1.484025  0.847369 -0.622034  1.166086 -0.385886 -1.149094
# ...         ...       ...       ...       ...       ...       ...       ...
# 97995  0.952911  0.408781  1.287093 -0.091769 -0.989367  0.153191  0.442240
# 97996  1.163371 -0.428415  0.267485  0.778516  0.138325  0.686528  0.627132
# 97997 -0.994402  1.448745  0.866627  0.164508  1.544230  1.185513  0.570752
# 97998  0.268791  0.513515  0.685678 -0.300550 -1.084287 -0.547494  0.107754
# 97999 -1.642028  1.119583 -1.199966  0.123089 -0.636083  1.000855 -0.314163
#
# [98000 rows x 29 columns]

# %%
import umap

umap_transform = umap.UMAP()

X_umap = umap_transform.fit_transform(data_norm)
X_umap
# Out:
# array([[10.862246 ,  3.2456381],
#        [ 8.86464  ,  4.6227384],
#        [ 7.6943274,  2.4513347],
#        ...,
#        [ 7.4224267,  2.1613524],
#        [ 7.135012 ,  4.228027 ],
#        [10.712758 ,  3.395196 ]], dtype=float32)

# %%
sns.scatterplot(X_umap, x=X_umap[:,0], y=X_umap[:,1], s=25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Number of clusters and K-Means
# First we choose the best number of clusters using DB index and Silhouette score

# %%
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import silhouette_score

# %%
def eval_clustering(X,cluster_func,score_func,**kwargs):

    scores = []

    for k in tqdm(kwargs["k_range"]):
        cluster = cluster_func(k,**kwargs["c_args"])
        labels = cluster.fit_predict(X)
        score = score_func(X,labels,**kwargs["s_args"]) if "s_args" in kwargs else score_func(X,labels)
        scores.append((k, score))

    return scores

# %%
def plot_scores(scores,k_range):
    ax_x, ax_y = zip(*scores)

    fig = plt.figure(figsize=(10,5))
    ax = plt.axes()
    plt.xticks(k_range)
    plt.grid()
    plt.plot(ax_x, ax_y)

# %% [markdown]
# As silthuette score takes a lot of time, we'll set the sample size to 10000

# %% [markdown]
# ### Silhouette score

# %%
from tqdm.notebook import tqdm
from sklearn.cluster import KMeans

k_range = range(2,20)

scores = eval_clustering(X_umap,
                         KMeans,
                         silhouette_score,
                         k_range = k_range,
                         c_args={
                             "init":"k-means++",
                             "n_init":1
                         },
                         s_args={
                             "metric":"euclidean",
                             "sample_size":10000
                         })
scores
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]

# %%
plot_scores(scores,k_range)

# %%
scores = eval_clustering(X_umap,
                         KMeans,
                         davies_bouldin_score,
                         k_range = k_range,
                         c_args={
                             "init":"k-means++",
                             "n_init":1
                         })
scores
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
# [(2, 0.9724775144619248),
#  (3, 0.8672294062413656),
#  (4, 0.8064658024628409),
#  (5, 0.8697321930956857),
#  (6, 0.8512331336069975),
#  (7, 0.8088278420089512),
#  (8, 0.8192054394758989),
#  (9, 0.8104028622097151),
#  (10, 0.8172285466309678),
#  (11, 0.8314693386895783),
#  (12, 0.8358381594908284),
#  (13, 0.8155080520436807),
#  (14, 0.8213387474182628),
#  (15, 0.8246334647903802),
#  (16, 0.8246043505343317),
#  (17, 0.8086979343966131),
#  (18, 0.8152847025188164),
#  (19, 0.7928538800374186)]

# %%
plot_scores(scores,k_range)

# %%
kmeans = KMeans(4,init="k-means++",n_init=1)
kmeans.fit_transform(data)
sns.scatterplot(X_umap, x=X_umap[:,0], y=X_umap[:,1],hue=kmeans.labels_, s=25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Perform on 3 as it's notable

# %%
kmeans = KMeans(3,init="k-means++",n_init=1)
kmeans.fit_transform(data)
sns.scatterplot(X_umap, x=X_umap[:,0], y=X_umap[:,1],hue=kmeans.labels_, s=25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### DB-Scan

# %% [markdown]
# First determine distances for min neighbors of 100

# %%
from sklearn.neighbors import NearestNeighbors

neighbors = NearestNeighbors(n_neighbors=100)
neighbors_fit = neighbors.fit(data_norm)
distances, indices = neighbors_fit.kneighbors(data_norm)

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %% [markdown]
# Best epsilon is somewhere from 4.5 to 5.0

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=4.9,min_samples=75)
labels = dbscan.fit_predict(data_norm)
sns.scatterplot(X_umap, x=X_umap[:,0], y=X_umap[:,1],hue=labels, s=25)
# Out:
# <AxesSubplot:>
